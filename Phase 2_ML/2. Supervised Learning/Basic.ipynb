# %% [markdown]
# # 📘 Supervised Machine Learning
#
# Today you will learn the foundation of ML: **Supervised Learning** — the most widely used ML category.
#
# You will learn:
#
# ✔ What is supervised learning
# ✔ Types: Regression vs Classification
# ✔ How training works
# ✔ Evaluation metrics
# ✔ Practice code (simple examples)
#
# ---
#
# ## 🔵 1. What is Supervised Learning?
#
# Supervised learning is when:
#
# - You have **input data (X)**
# - You have **correct answers (y)**
# - The model learns to **predict y from X**
#
# ### Example:
#
# | X (Features) | y (Target) |
# |--------------|------------|
# | Study hours  | Score      |
# | Salary, Age  | Loan approval (Yes/No) |
# | Size of house | House price |
#
# Your job: Give the computer many examples so it learns the pattern.
#
# ---
#
# ## 🔵 2. Types of Supervised Learning
#
# ### 1️⃣ Regression
# Predicts **continuous numbers**.
#
# #### Examples:
# - House prices
# - Salary prediction
# - Temperature prediction
#
# #### Algorithms:
# - Linear Regression
# - Polynomial Regression
# - Decision Tree Regressor
# - Random Forest Regressor
#
# ### 2️⃣ Classification
# Predicts **categories/labels**.
#
# #### Examples:
# - Spam / Not spam
# - Disease: Yes / No
# - Handwritten digits (0–9)
#
# #### Algorithms:
# - Logistic Regression
# - KNN
# - SVM
# - Decision Tree Classifier
# - Random Forest Classifier
#
# ---
#
# ## 🔵 3. How Supervised Learning Works
#
# ### **Step 1 — Split dataset**
#
# ```python
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### **Step 2 — Choose a model**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

#Step 3 — Train the model
model.fit(X_train, y_train)

#Step 4 — Predict
y_pred = model.predict(X_test)

# %% [markdown]
# ### 🔵 4. Evaluation Metrics
# ✔ Regression Metrics\
# MAE (Mean Absolute Error)\
# MSE (Mean Squared Error)\
# RMSE (Root Mean Squared Error)\
# R² Score

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %% [markdown]
# ### ✔ Classification Metrics
#
# Accuracy\
# Precision\
# Recall\
# F1-score\
# Confusion Matrix

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# ## Practice Example (Regression)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Data: Hours studied vs Marks
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([40, 50, 60, 70, 80])

model = LinearRegression()
model.fit(X, y)

print(model.predict([[6]]))  # Expected ~90

# %% [markdown]
# ## Practice Example (Classification)

# %%
from sklearn.neighbors import KNeighborsClassifier

X = [[150, 0], [160, 0], [170, 1], [180, 1]]  # (height, gender)
y = ["M", "M", "F", "F"]

model = KNeighborsClassifier(n_neighbors=1)
model.fit(X, y)

print(model.predict([[165, 0]]))
