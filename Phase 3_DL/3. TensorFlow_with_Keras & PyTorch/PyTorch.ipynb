# %% [markdown]
# # PyTorch
#
# **PyTorch** is a deep learning framework that is **lower-level, highly flexible, and research-friendly**.
# 👉 Think of **PyTorch = “Deep Learning with full control”**
#
# ---
#
# ## 🧩 1️⃣ PyTorch — Basics
#
# | Concept     | PyTorch Implementation        |
# |------------|-------------------------------|
# | Tensor     | `torch.tensor`                |
# | Model      | `nn.Module`                   |
# | Layer      | `nn.Linear`                   |
# | Activation | `torch.relu()`                |
# | Loss       | `nn.CrossEntropyLoss`         |
# | Optimizer  | `torch.optim`                 |
#
# ---

# %% [markdown]
# ## 🟢 2️⃣ First PyTorch Model (Single Neuron)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Data
X = torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = torch.tensor([[0.],[1.],[1.],[1.]])

# Model
model = nn.Sequential(
    nn.Linear(2,1),
    nn.Sigmoid()
)

# Loss & optimizer
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Training
for epoch in range(1000):
    optimizer.zero_grad()
    y_pred = model(X)
    loss = criterion(y_pred, y)
    loss.backward()
    optimizer.step()

print(model(X).round())

# %% [markdown]
# ✅ You see backprop explicitly (loss.backward()).

# %% [markdown]
# ## 🔵 3️⃣ Multi-Layer PyTorch Network

# %%
class NeuralNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 16)
        self.fc2 = nn.Linear(16, 8)
        self.fc3 = nn.Linear(8, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return torch.sigmoid(self.fc3(x))


model = NeuralNet()

# %% [markdown]
# ## 🟣 4️⃣ Advanced PyTorch Example (MNIST)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.ToTensor()

train_data = datasets.MNIST(".", train=True, download=True, transform=transform)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)

model = nn.Sequential(nn.Flatten(), nn.Linear(784, 128), nn.ReLU(), nn.Linear(128, 10))

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(5):
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

# %% [markdown]
# ## ⚔️ Keras vs PyTorch (VERY IMPORTANT)
#
# | Feature      | Keras       | PyTorch        |
# |-------------|-------------|----------------|
# | Ease of Use | ⭐⭐⭐⭐⭐      | ⭐⭐⭐            |
# | Control     | ⭐⭐          | ⭐⭐⭐⭐⭐         |
# | Debugging   | Easy        | Very Easy      |
# | Research    | Good        | Best           |
# | Production  | Excellent   | Excellent      |
#
# ---
